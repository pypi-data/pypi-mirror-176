# %% [markdown]
# ***安装本教材配套模块***

# %%
# !pip install -U python-education-tools
# Out:
# Requirement already satisfied: python-education-tools in c:\python\python310\lib\site-packages (0.2.5)

# %% [markdown]
# Python程序代码示例

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Feb 25 09:07:47 2020
@author: Administrator
"""
import datetime
# 获取当前时间
t=datetime.datetime.now()

def hi(name):
    """
     Parameters
    ----------
    f : list
        files and directories list
    Returns
    -------
    flpy : list
        list only contains python files.
    """
    return 'hello:'+ str(name)

if __name__ == "__main__":
    print(t)
    print(hi('James'))
# Out:
# 2022-08-03 20:04:54.966947
# hello:James

# %%
# 第一个注释
print ("Hello world！, Python!")
# Out:
# Hello world！, Python!

# %%
# !pip install -U pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in c:\python\python310\lib\site-packages (2.90)
# Requirement already satisfied: pywin32 in c:\python\python310\lib\site-packages (from pyttsx3) (303)
# Requirement already satisfied: comtypes in c:\python\python310\lib\site-packages (from pyttsx3) (1.1.11)
# Requirement already satisfied: pypiwin32 in c:\python\python310\lib\site-packages (from pyttsx3) (223)

# %%
import pyttsx3
engine = pyttsx3.init()
engine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')
engine.runAndWait()

# %% [markdown]
# 查看__doc__属性

# %%
help(hi)
# Out:
# Help on function hi in module __main__:
#
# hi(name)
#      Parameters
#     ----------
#     f : list
#         files and directories list
#     Returns
#     -------
#     flpy : list
#         list only contains python files.

# %%
print(hi.__doc__)
# Out:
#      Parameters
#     ----------
#     f : list
#         files and directories list
#     Returns
#     -------
#     flpy : list
#         list only contains python files.

# %%
if True:
    print ("True")
else:
    print ("False")
# Out:
# True

# %%
if True:
    print ("Answer")
    print ("True")
else:
    print ("Answer")
  print ("False")    # 缩进不一致，会导致运行错误
# Out:
#   File "<tokenize>", line 6
#     print ("False")    # 缩进不一致，会导致运行错误
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# Python语言一行长代码换行写法代码示例。

# %%
total ="A33"\
       "B44"\
       "C55"
print(total)
#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\)，例如：
total = ['item_one', 'item_two', 'item_three',
        'item_four', 'item_five']

# %% [markdown]
# ![关键词](img\img_1.png)

# %%
import keyword
print(keyword.kwlist)  #关键字列表
print(len(keyword.kwlist)) #统计关键字的个数
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
const=[False,True,None,NotImplemented,Ellipsis,__debug__]
for i in const:
    print(f'value is {i}, type is {type(i)}')
# Out:
# value is False, type is <class 'bool'>
# value is True, type is <class 'bool'>
# value is None, type is <class 'NoneType'>
# value is NotImplemented, type is <class 'NotImplementedType'>
# value is Ellipsis, type is <class 'ellipsis'>
# value is True, type is <class 'bool'>

# %% [markdown]
# ![内部函数](img\img_1.png)

# %% [markdown]
# [内部函数](https://docs.python.org/3.9/library/functions.html)

# %%
dir()
# Out:
# ['DataFrame',
#  'In',
#  'MultiIndex',
#  'Out',
#  '_',
#  '_14',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_38',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_pydevd_bundle',
#  'const',
#  'dao',
#  'datetime',
#  'engine',
#  'exit',
#  'get_ipython',
#  'hi',
#  'i',
#  'inp',
#  'keyword',
#  'matches',
#  'print_columns',
#  'pydev_jupyter_vars',
#  'pyttsx3',
#  'quit',
#  're',
#  'remove_imported_pydev_package',
#  's',
#  'sys',
#  't',
#  'total',
#  'x']

# %%
x=100
dir()
# Out:
# ['DataFrame',
#  'In',
#  'MultiIndex',
#  'Out',
#  '_',
#  '_14',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_38',
#  '_51',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_pydevd_bundle',
#  'const',
#  'dao',
#  'datetime',
#  'engine',
#  'exit',
#  'get_ipython',
#  'hi',
#  'i',
#  'inp',
#  'keyword',
#  'matches',
#  'print_columns',
#  'pydev_jupyter_vars',
#  'pyttsx3',
#  'quit',
#  're',
#  'remove_imported_pydev_package',
#  's',
#  'sys',
#  't',
#  'total',
#  'x']

# %% [markdown]
# 定义一个函数后的命名空间

# %%
def s(length):
	x=300
	y=400
dir()
# Out:
# ['DataFrame',
#  'In',
#  'MultiIndex',
#  'Out',
#  '_',
#  '_14',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_38',
#  '_51',
#  '_52',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i53',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_pydevd_bundle',
#  'const',
#  'dao',
#  'datetime',
#  'engine',
#  'exit',
#  'get_ipython',
#  'hi',
#  'i',
#  'inp',
#  'keyword',
#  'matches',
#  'print_columns',
#  'pydev_jupyter_vars',
#  'pyttsx3',
#  'quit',
#  're',
#  'remove_imported_pydev_package',
#  's',
#  'sys',
#  't',
#  'total',
#  'x']

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': '\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!") ',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   'import pyttsx3\nfrom pet.dao import dao\nengine = pyttsx3.init()\nengine.say(dao.dao)\nengine.runAndWait()',
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   '查看__doc__属性',
#   '查看__doc__属性',
#   'hi(name)\n     Parameters\n    ----------\n    name : string\n        a string,such as name\n    Returns\n    -------\n    flpy : string\n        hello + string',
#   'help(hi)',
#   'hi.__doc__',
#   'print(hi.__doc__)',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'([A-Z]+)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (A)"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'(\\([A-Z]+\\)\\s*(\\w+))|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']\nA33B44C55',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value{i=}, type{type(i)=}')",
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()',
#   'locals()',
#   'vars()',
#   "get_ipython().system('pip install -U python-education-tools')",
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   'help(hi)',
#   'print(hi.__doc__)',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()'],
#  '_oh': {14: '\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    ',
#   32: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total'],
#   33: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   34: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   35: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   36: {...},
#   37: {...},
#   38: {...},
#   51: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   52: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   53: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '_52',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i53',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x']},
#  '_dh': ['C:\\Users\\Administrator\\Desktop\\2022年7月\\python_education_tools\\src\\pet\\textbook1'],
#  'In': ['',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!") ',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   'import pyttsx3\nfrom pet.dao import dao\nengine = pyttsx3.init()\nengine.say(dao.dao)\nengine.runAndWait()',
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   '查看__doc__属性',
#   '查看__doc__属性',
#   'hi(name)\n     Parameters\n    ----------\n    name : string\n        a string,such as name\n    Returns\n    -------\n    flpy : string\n        hello + string',
#   'help(hi)',
#   'hi.__doc__',
#   'print(hi.__doc__)',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'([A-Z]+)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (A)"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'(\\([A-Z]+\\)\\s*(\\w+))|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']\nA33B44C55',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value{i=}, type{type(i)=}')",
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()',
#   'locals()',
#   'vars()',
#   "get_ipython().system('pip install -U python-education-tools')",
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   'help(hi)',
#   'print(hi.__doc__)',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()'],
#  'Out': {14: '\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    ',
#   32: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total'],
#   33: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   34: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   35: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   36: {...},
#   37: {...},
#   38: {...},
#   51: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   52: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   53: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '_52',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i53',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x']},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000276FEA40BB0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x276fea42290>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x276fea42290>,
#  '_': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '_52',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i53',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '__': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '___': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i': 'def s(length):\n\tx=300\n\ty=400\ndir()',
#  '_ii': 'x=100\ndir()',
#  '_iii': 'dir()',
#  '_i1': '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
#  'sys': <module 'sys' (built-in)>,
#  'remove_imported_pydev_package': <function pydev_jupyter_utils.remove_imported_pydev_package()>,
#  '_pydevd_bundle': <module '_pydevd_bundle' from 'C:\\Users\\Administrator\\AppData\\Local\\JetBrains\\Toolbox\\apps\\PyCharm-P\\ch-0\\221.5921.27\\plugins\\python\\helpers\\pydev\\_pydevd_bundle\\__init__.py'>,
#  'pydev_jupyter_vars': <module 'pydev_jupyter_vars' from 'C:\\Users\\Administrator\\AppData\\Local\\JetBrains\\Toolbox\\apps\\PyCharm-P\\ch-0\\221.5921.27\\plugins\\python\\helpers-pro\\jupyter_debug\\pydev_jupyter_vars.py'>,
#  '_i3': '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#  'datetime': <module 'datetime' from 'C:\\Python\\Python310\\lib\\datetime.py'>,
#  't': datetime.datetime(2022, 8, 3, 20, 4, 54, 966947),
#  'hi': <function __main__.hi(name)>,
#  '_i4': '# 第一个注释\nprint ("Hello world！, Python!") ',
#  '_i5': '# 第一个注释\nprint ("Hello world！, Python!")',
#  '_i6': '!pip install -U pyttsx3',
#  '_exit_code': 0,
#  'DataFrame': pandas.core.frame.DataFrame,
#  'MultiIndex': pandas.core.indexes.multi.MultiIndex,
#  'print_columns': <function __main__.print_columns(name, column_number)>,
#  '_i7': 'import pyttsx3\nfrom pet.dao import dao\nengine = pyttsx3.init()\nengine.say(dao.dao)\nengine.runAndWait()',
#  'pyttsx3': <module 'pyttsx3' from 'C:\\Python\\Python310\\lib\\site-packages\\pyttsx3\\__init__.py'>,
#  'dao': '\n                   编程之道：\n  "大道无形，生育天地；大道无情，运行日月；大道无名，长养万物；吾不知其名，强名曰道。"  编程之道，起于心，行于术，得于道。\n  心为万之源，心静万物自然静。"常能遣其欲，而心自静，澄其心而神自清。心静至极"，"泰山崩于前而色不变，麋鹿兴于左而目不瞬，然后可以制利害，可以待敌。"\n  为学日益，术业虽有专攻，然更相通。编程之术无异于雕塑、工笔水墨，多一行代码冗余，少一行代码则不足。\n  为道日损，"秉之御繁以简，常得无事"。大道至简，以简驭繁。理不简，则道不明！\n  “信言不美，美言不信。善者不辩，辩者不善。知者不博，博者不知。圣人不积，既以为人己愈有，既以与人己愈多。天之道，利而不害。人之道，为而不争。”\n\n                                    From: 道法自然 Prof.Li (liluqun@gmail.com)\n                                    参考：《道德经》、《太上老君清静经》、《权书·心术》\n',
#  'engine': <pyttsx3.engine.Engine at 0x2768fc858d0>,
#  '_i8': "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#  '_i9': '查看__doc__属性',
#  '_i10': '查看__doc__属性',
#  '_i11': 'hi(name)\n     Parameters\n    ----------\n    name : string\n        a string,such as name\n    Returns\n    -------\n    flpy : string\n        hello + string',
#  '_i13': 'help(hi)',
#  '_i14': 'hi.__doc__',
#  '_14': '\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    ',
#  '_i15': 'print(hi.__doc__)',
#  '_i16': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  're': <module 're' from 'C:\\Python\\Python310\\lib\\re.py'>,
#  'inp': '(A) gre (B)Toefl (C)PET (D)CET [A])',
#  'matches': [('gre', ''), ('Toefl', ''), ('PET', ''), ('CET', '')],
#  '_i17': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'([A-Z]+)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i18': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i19': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (A)"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i20': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i21': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i22': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'(\\([A-Z]+\\)\\s*(\\w+))|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i23': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i24': 'if True:\n    print ("True")\nelse:\n    print ("False")',
#  '_i25': 'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#  '_i27': 'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']\nA33B44C55',
#  'total': ['item_one', 'item_two', 'item_three', 'item_four', 'item_five'],
#  '_i28': 'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']',
#  '_i29': 'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#  'keyword': <module 'keyword' from 'C:\\Python\\Python310\\lib\\keyword.py'>,
#  '_i30': "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value{i=}, type{type(i)=}')",
#  'const': [False, True, None, NotImplemented, Ellipsis, True],
#  'i': True,
#  '_i31': "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#  '_i32': 'dir()',
#  '_32': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   'sys',
#   't',
#   'total'],
#  '_i33': 'x=100\ndir()',
#  'x': 100,
#  '_33': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i34': 'x=100\ndir()',
#  '_34': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i35': 'def s(length):\n\tx=300\n\ty=400\ndir()',
#  's': <function __main__.s(length)>,
#  '_35': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i36': 'globals()',
#  '_36': {...},
#  '_i37': 'locals()',
#  '_37': {...},
#  '_i38': 'vars()',
#  '_38': {...},
#  '_i39': '!pip install -U python-education-tools',
#  '_i40': '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#  '_i41': '# 第一个注释\nprint ("Hello world！, Python!")',
#  '_i42': '!pip install -U pyttsx3',
#  '_i43': "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#  '_i44': 'help(hi)',
#  '_i45': 'print(hi.__doc__)',
#  '_i46': 'if True:\n    print ("True")\nelse:\n    print ("False")',
#  '_i47': 'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#  '_i49': 'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#  '_i50': "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#  '_i51': 'dir()',
#  '_51': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i52': 'x=100\ndir()',
#  '_52': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i53': 'def s(length):\n\tx=300\n\ty=400\ndir()',
#  '_53': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '_52',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i53',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i54': 'globals()'}

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': '\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!") ',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   'import pyttsx3\nfrom pet.dao import dao\nengine = pyttsx3.init()\nengine.say(dao.dao)\nengine.runAndWait()',
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   '查看__doc__属性',
#   '查看__doc__属性',
#   'hi(name)\n     Parameters\n    ----------\n    name : string\n        a string,such as name\n    Returns\n    -------\n    flpy : string\n        hello + string',
#   'help(hi)',
#   'hi.__doc__',
#   'print(hi.__doc__)',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'([A-Z]+)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (A)"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'(\\([A-Z]+\\)\\s*(\\w+))|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']\nA33B44C55',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value{i=}, type{type(i)=}')",
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()',
#   'locals()',
#   'vars()',
#   "get_ipython().system('pip install -U python-education-tools')",
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   'help(hi)',
#   'print(hi.__doc__)',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()',
#   'locals()'],
#  '_oh': {14: '\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    ',
#   32: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total'],
#   33: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   34: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   35: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   36: {...},
#   37: {...},
#   38: {...},
#   51: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   52: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   53: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '_52',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i53',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   54: {...}},
#  '_dh': ['C:\\Users\\Administrator\\Desktop\\2022年7月\\python_education_tools\\src\\pet\\textbook1'],
#  'In': ['',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!") ',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   'import pyttsx3\nfrom pet.dao import dao\nengine = pyttsx3.init()\nengine.say(dao.dao)\nengine.runAndWait()',
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   '查看__doc__属性',
#   '查看__doc__属性',
#   'hi(name)\n     Parameters\n    ----------\n    name : string\n        a string,such as name\n    Returns\n    -------\n    flpy : string\n        hello + string',
#   'help(hi)',
#   'hi.__doc__',
#   'print(hi.__doc__)',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'([A-Z]+)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (A)"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'(\\([A-Z]+\\)\\s*(\\w+))|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']\nA33B44C55',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value{i=}, type{type(i)=}')",
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()',
#   'locals()',
#   'vars()',
#   "get_ipython().system('pip install -U python-education-tools')",
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   'help(hi)',
#   'print(hi.__doc__)',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()',
#   'locals()'],
#  'Out': {14: '\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    ',
#   32: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total'],
#   33: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   34: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   35: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   36: {...},
#   37: {...},
#   38: {...},
#   51: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   52: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   53: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '_52',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i53',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   54: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000276FEA40BB0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x276fea42290>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x276fea42290>,
#  '_': {...},
#  '__': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '_52',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i53',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '___': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i': 'globals()',
#  '_ii': 'def s(length):\n\tx=300\n\ty=400\ndir()',
#  '_iii': 'x=100\ndir()',
#  '_i1': '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
#  'sys': <module 'sys' (built-in)>,
#  'remove_imported_pydev_package': <function pydev_jupyter_utils.remove_imported_pydev_package()>,
#  '_pydevd_bundle': <module '_pydevd_bundle' from 'C:\\Users\\Administrator\\AppData\\Local\\JetBrains\\Toolbox\\apps\\PyCharm-P\\ch-0\\221.5921.27\\plugins\\python\\helpers\\pydev\\_pydevd_bundle\\__init__.py'>,
#  'pydev_jupyter_vars': <module 'pydev_jupyter_vars' from 'C:\\Users\\Administrator\\AppData\\Local\\JetBrains\\Toolbox\\apps\\PyCharm-P\\ch-0\\221.5921.27\\plugins\\python\\helpers-pro\\jupyter_debug\\pydev_jupyter_vars.py'>,
#  '_i3': '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#  'datetime': <module 'datetime' from 'C:\\Python\\Python310\\lib\\datetime.py'>,
#  't': datetime.datetime(2022, 8, 3, 20, 4, 54, 966947),
#  'hi': <function __main__.hi(name)>,
#  '_i4': '# 第一个注释\nprint ("Hello world！, Python!") ',
#  '_i5': '# 第一个注释\nprint ("Hello world！, Python!")',
#  '_i6': '!pip install -U pyttsx3',
#  '_exit_code': 0,
#  'DataFrame': pandas.core.frame.DataFrame,
#  'MultiIndex': pandas.core.indexes.multi.MultiIndex,
#  'print_columns': <function __main__.print_columns(name, column_number)>,
#  '_i7': 'import pyttsx3\nfrom pet.dao import dao\nengine = pyttsx3.init()\nengine.say(dao.dao)\nengine.runAndWait()',
#  'pyttsx3': <module 'pyttsx3' from 'C:\\Python\\Python310\\lib\\site-packages\\pyttsx3\\__init__.py'>,
#  'dao': '\n                   编程之道：\n  "大道无形，生育天地；大道无情，运行日月；大道无名，长养万物；吾不知其名，强名曰道。"  编程之道，起于心，行于术，得于道。\n  心为万之源，心静万物自然静。"常能遣其欲，而心自静，澄其心而神自清。心静至极"，"泰山崩于前而色不变，麋鹿兴于左而目不瞬，然后可以制利害，可以待敌。"\n  为学日益，术业虽有专攻，然更相通。编程之术无异于雕塑、工笔水墨，多一行代码冗余，少一行代码则不足。\n  为道日损，"秉之御繁以简，常得无事"。大道至简，以简驭繁。理不简，则道不明！\n  “信言不美，美言不信。善者不辩，辩者不善。知者不博，博者不知。圣人不积，既以为人己愈有，既以与人己愈多。天之道，利而不害。人之道，为而不争。”\n\n                                    From: 道法自然 Prof.Li (liluqun@gmail.com)\n                                    参考：《道德经》、《太上老君清静经》、《权书·心术》\n',
#  'engine': <pyttsx3.engine.Engine at 0x2768fc858d0>,
#  '_i8': "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#  '_i9': '查看__doc__属性',
#  '_i10': '查看__doc__属性',
#  '_i11': 'hi(name)\n     Parameters\n    ----------\n    name : string\n        a string,such as name\n    Returns\n    -------\n    flpy : string\n        hello + string',
#  '_i13': 'help(hi)',
#  '_i14': 'hi.__doc__',
#  '_14': '\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    ',
#  '_i15': 'print(hi.__doc__)',
#  '_i16': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  're': <module 're' from 'C:\\Python\\Python310\\lib\\re.py'>,
#  'inp': '(A) gre (B)Toefl (C)PET (D)CET [A])',
#  'matches': [('gre', ''), ('Toefl', ''), ('PET', ''), ('CET', '')],
#  '_i17': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'([A-Z]+)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i18': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i19': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (A)"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i20': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i21': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i22': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'(\\([A-Z]+\\)\\s*(\\w+))|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i23': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i24': 'if True:\n    print ("True")\nelse:\n    print ("False")',
#  '_i25': 'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#  '_i27': 'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']\nA33B44C55',
#  'total': ['item_one', 'item_two', 'item_three', 'item_four', 'item_five'],
#  '_i28': 'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']',
#  '_i29': 'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#  'keyword': <module 'keyword' from 'C:\\Python\\Python310\\lib\\keyword.py'>,
#  '_i30': "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value{i=}, type{type(i)=}')",
#  'const': [False, True, None, NotImplemented, Ellipsis, True],
#  'i': True,
#  '_i31': "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#  '_i32': 'dir()',
#  '_32': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   'sys',
#   't',
#   'total'],
#  '_i33': 'x=100\ndir()',
#  'x': 100,
#  '_33': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i34': 'x=100\ndir()',
#  '_34': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i35': 'def s(length):\n\tx=300\n\ty=400\ndir()',
#  's': <function __main__.s(length)>,
#  '_35': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i36': 'globals()',
#  '_36': {...},
#  '_i37': 'locals()',
#  '_37': {...},
#  '_i38': 'vars()',
#  '_38': {...},
#  '_i39': '!pip install -U python-education-tools',
#  '_i40': '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#  '_i41': '# 第一个注释\nprint ("Hello world！, Python!")',
#  '_i42': '!pip install -U pyttsx3',
#  '_i43': "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#  '_i44': 'help(hi)',
#  '_i45': 'print(hi.__doc__)',
#  '_i46': 'if True:\n    print ("True")\nelse:\n    print ("False")',
#  '_i47': 'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#  '_i49': 'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#  '_i50': "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#  '_i51': 'dir()',
#  '_51': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i52': 'x=100\ndir()',
#  '_52': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i53': 'def s(length):\n\tx=300\n\ty=400\ndir()',
#  '_53': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '_52',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i53',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i54': 'globals()',
#  '_54': {...},
#  '_i55': 'locals()'}

# %%
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': '\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!") ',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   'import pyttsx3\nfrom pet.dao import dao\nengine = pyttsx3.init()\nengine.say(dao.dao)\nengine.runAndWait()',
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   '查看__doc__属性',
#   '查看__doc__属性',
#   'hi(name)\n     Parameters\n    ----------\n    name : string\n        a string,such as name\n    Returns\n    -------\n    flpy : string\n        hello + string',
#   'help(hi)',
#   'hi.__doc__',
#   'print(hi.__doc__)',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'([A-Z]+)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (A)"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'(\\([A-Z]+\\)\\s*(\\w+))|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']\nA33B44C55',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value{i=}, type{type(i)=}')",
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()',
#   'locals()',
#   'vars()',
#   "get_ipython().system('pip install -U python-education-tools')",
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   'help(hi)',
#   'print(hi.__doc__)',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()',
#   'locals()',
#   'vars()'],
#  '_oh': {14: '\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    ',
#   32: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total'],
#   33: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   34: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   35: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   36: {...},
#   37: {...},
#   38: {...},
#   51: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   52: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   53: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '_52',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i53',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   54: {...},
#   55: {...}},
#  '_dh': ['C:\\Users\\Administrator\\Desktop\\2022年7月\\python_education_tools\\src\\pet\\textbook1'],
#  'In': ['',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!") ',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   'import pyttsx3\nfrom pet.dao import dao\nengine = pyttsx3.init()\nengine.say(dao.dao)\nengine.runAndWait()',
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   '查看__doc__属性',
#   '查看__doc__属性',
#   'hi(name)\n     Parameters\n    ----------\n    name : string\n        a string,such as name\n    Returns\n    -------\n    flpy : string\n        hello + string',
#   'help(hi)',
#   'hi.__doc__',
#   'print(hi.__doc__)',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'([A-Z]+)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (A)"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'(\\([A-Z]+\\)\\s*(\\w+))|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']\nA33B44C55',
#   'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value{i=}, type{type(i)=}')",
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()',
#   'locals()',
#   'vars()',
#   "get_ipython().system('pip install -U python-education-tools')",
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#   '# 第一个注释\nprint ("Hello world！, Python!")',
#   "get_ipython().system('pip install -U pyttsx3')",
#   "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#   'help(hi)',
#   'print(hi.__doc__)',
#   'if True:\n    print ("True")\nelse:\n    print ("False")',
#   'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#   'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#   "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#   'dir()',
#   'x=100\ndir()',
#   'def s(length):\n\tx=300\n\ty=400\ndir()',
#   'globals()',
#   'locals()',
#   'vars()'],
#  'Out': {14: '\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    ',
#   32: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total'],
#   33: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   34: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    'sys',
#    't',
#    'total',
#    'x'],
#   35: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   36: {...},
#   37: {...},
#   38: {...},
#   51: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   52: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   53: ['DataFrame',
#    'In',
#    'MultiIndex',
#    'Out',
#    '_',
#    '_14',
#    '_32',
#    '_33',
#    '_34',
#    '_35',
#    '_36',
#    '_37',
#    '_38',
#    '_51',
#    '_52',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_exit_code',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i11',
#    '_i13',
#    '_i14',
#    '_i15',
#    '_i16',
#    '_i17',
#    '_i18',
#    '_i19',
#    '_i20',
#    '_i21',
#    '_i22',
#    '_i23',
#    '_i24',
#    '_i25',
#    '_i27',
#    '_i28',
#    '_i29',
#    '_i3',
#    '_i30',
#    '_i31',
#    '_i32',
#    '_i33',
#    '_i34',
#    '_i35',
#    '_i36',
#    '_i37',
#    '_i38',
#    '_i39',
#    '_i4',
#    '_i40',
#    '_i41',
#    '_i42',
#    '_i43',
#    '_i44',
#    '_i45',
#    '_i46',
#    '_i47',
#    '_i49',
#    '_i5',
#    '_i50',
#    '_i51',
#    '_i52',
#    '_i53',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    '_pydevd_bundle',
#    'const',
#    'dao',
#    'datetime',
#    'engine',
#    'exit',
#    'get_ipython',
#    'hi',
#    'i',
#    'inp',
#    'keyword',
#    'matches',
#    'print_columns',
#    'pydev_jupyter_vars',
#    'pyttsx3',
#    'quit',
#    're',
#    'remove_imported_pydev_package',
#    's',
#    'sys',
#    't',
#    'total',
#    'x'],
#   54: {...},
#   55: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000276FEA40BB0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x276fea42290>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x276fea42290>,
#  '_': {...},
#  '__': {...},
#  '___': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '_52',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i53',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i': 'locals()',
#  '_ii': 'globals()',
#  '_iii': 'def s(length):\n\tx=300\n\ty=400\ndir()',
#  '_i1': '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
#  'sys': <module 'sys' (built-in)>,
#  'remove_imported_pydev_package': <function pydev_jupyter_utils.remove_imported_pydev_package()>,
#  '_pydevd_bundle': <module '_pydevd_bundle' from 'C:\\Users\\Administrator\\AppData\\Local\\JetBrains\\Toolbox\\apps\\PyCharm-P\\ch-0\\221.5921.27\\plugins\\python\\helpers\\pydev\\_pydevd_bundle\\__init__.py'>,
#  'pydev_jupyter_vars': <module 'pydev_jupyter_vars' from 'C:\\Users\\Administrator\\AppData\\Local\\JetBrains\\Toolbox\\apps\\PyCharm-P\\ch-0\\221.5921.27\\plugins\\python\\helpers-pro\\jupyter_debug\\pydev_jupyter_vars.py'>,
#  '_i3': '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#  'datetime': <module 'datetime' from 'C:\\Python\\Python310\\lib\\datetime.py'>,
#  't': datetime.datetime(2022, 8, 3, 20, 4, 54, 966947),
#  'hi': <function __main__.hi(name)>,
#  '_i4': '# 第一个注释\nprint ("Hello world！, Python!") ',
#  '_i5': '# 第一个注释\nprint ("Hello world！, Python!")',
#  '_i6': '!pip install -U pyttsx3',
#  '_exit_code': 0,
#  'DataFrame': pandas.core.frame.DataFrame,
#  'MultiIndex': pandas.core.indexes.multi.MultiIndex,
#  'print_columns': <function __main__.print_columns(name, column_number)>,
#  '_i7': 'import pyttsx3\nfrom pet.dao import dao\nengine = pyttsx3.init()\nengine.say(dao.dao)\nengine.runAndWait()',
#  'pyttsx3': <module 'pyttsx3' from 'C:\\Python\\Python310\\lib\\site-packages\\pyttsx3\\__init__.py'>,
#  'dao': '\n                   编程之道：\n  "大道无形，生育天地；大道无情，运行日月；大道无名，长养万物；吾不知其名，强名曰道。"  编程之道，起于心，行于术，得于道。\n  心为万之源，心静万物自然静。"常能遣其欲，而心自静，澄其心而神自清。心静至极"，"泰山崩于前而色不变，麋鹿兴于左而目不瞬，然后可以制利害，可以待敌。"\n  为学日益，术业虽有专攻，然更相通。编程之术无异于雕塑、工笔水墨，多一行代码冗余，少一行代码则不足。\n  为道日损，"秉之御繁以简，常得无事"。大道至简，以简驭繁。理不简，则道不明！\n  “信言不美，美言不信。善者不辩，辩者不善。知者不博，博者不知。圣人不积，既以为人己愈有，既以与人己愈多。天之道，利而不害。人之道，为而不争。”\n\n                                    From: 道法自然 Prof.Li (liluqun@gmail.com)\n                                    参考：《道德经》、《太上老君清静经》、《权书·心术》\n',
#  'engine': <pyttsx3.engine.Engine at 0x2768fc858d0>,
#  '_i8': "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#  '_i9': '查看__doc__属性',
#  '_i10': '查看__doc__属性',
#  '_i11': 'hi(name)\n     Parameters\n    ----------\n    name : string\n        a string,such as name\n    Returns\n    -------\n    flpy : string\n        hello + string',
#  '_i13': 'help(hi)',
#  '_i14': 'hi.__doc__',
#  '_14': '\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    ',
#  '_i15': 'print(hi.__doc__)',
#  '_i16': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  're': <module 're' from 'C:\\Python\\Python310\\lib\\re.py'>,
#  'inp': '(A) gre (B)Toefl (C)PET (D)CET [A])',
#  'matches': [('gre', ''), ('Toefl', ''), ('PET', ''), ('CET', '')],
#  '_i17': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'([A-Z]+)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i18': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (E)lll"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i19': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET (A)"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i20': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i21': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|\\[A-D]\\]\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i22': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'(\\([A-Z]+\\)\\s*(\\w+))|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i23': 'import re\ninp = "(A) gre (B)Toefl (C)PET (D)CET [A])"\nmatches = re.findall(r\'\\([A-Z]+\\)\\s*(\\w+)|(\\[A-D]\\])\', inp)\nprint(matches)  # [\'gre\', \'Toefl\', \'PET\', \'CET\']',
#  '_i24': 'if True:\n    print ("True")\nelse:\n    print ("False")',
#  '_i25': 'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#  '_i27': 'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']\nA33B44C55',
#  'total': ['item_one', 'item_two', 'item_three', 'item_four', 'item_five'],
#  '_i28': 'total ="A33"\\\n       "B44"\\\n       "C55"\nprint(total)\n#在 [], {}, 或 () 中的多行语句，不需要使用反斜杠(\\)，例如：\ntotal = [\'item_one\', \'item_two\', \'item_three\',\n        \'item_four\', \'item_five\']',
#  '_i29': 'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#  'keyword': <module 'keyword' from 'C:\\Python\\Python310\\lib\\keyword.py'>,
#  '_i30': "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value{i=}, type{type(i)=}')",
#  'const': [False, True, None, NotImplemented, Ellipsis, True],
#  'i': True,
#  '_i31': "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#  '_i32': 'dir()',
#  '_32': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   'sys',
#   't',
#   'total'],
#  '_i33': 'x=100\ndir()',
#  'x': 100,
#  '_33': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i34': 'x=100\ndir()',
#  '_34': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i35': 'def s(length):\n\tx=300\n\ty=400\ndir()',
#  's': <function __main__.s(length)>,
#  '_35': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i36': 'globals()',
#  '_36': {...},
#  '_i37': 'locals()',
#  '_37': {...},
#  '_i38': 'vars()',
#  '_38': {...},
#  '_i39': '!pip install -U python-education-tools',
#  '_i40': '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n    return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))',
#  '_i41': '# 第一个注释\nprint ("Hello world！, Python!")',
#  '_i42': '!pip install -U pyttsx3',
#  '_i43': "import pyttsx3\nengine = pyttsx3.init()\nengine.say('欢迎进入Python世界！！欢迎使用 Python Education Tools')\nengine.runAndWait()",
#  '_i44': 'help(hi)',
#  '_i45': 'print(hi.__doc__)',
#  '_i46': 'if True:\n    print ("True")\nelse:\n    print ("False")',
#  '_i47': 'if True:\n    print ("Answer")\n    print ("True")\nelse:\n    print ("Answer")\n  print ("False")    # 缩进不一致，会导致运行错误',
#  '_i49': 'import keyword\nprint(keyword.kwlist)  #关键字列表\nprint(len(keyword.kwlist)) #统计关键字的个数',
#  '_i50': "const=[False,True,None,NotImplemented,Ellipsis,__debug__]\nfor i in const:\n    print(f'value is {i}, type is {type(i)}')",
#  '_i51': 'dir()',
#  '_51': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i52': 'x=100\ndir()',
#  '_52': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i53': 'def s(length):\n\tx=300\n\ty=400\ndir()',
#  '_53': ['DataFrame',
#   'In',
#   'MultiIndex',
#   'Out',
#   '_',
#   '_14',
#   '_32',
#   '_33',
#   '_34',
#   '_35',
#   '_36',
#   '_37',
#   '_38',
#   '_51',
#   '_52',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_exit_code',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i11',
#   '_i13',
#   '_i14',
#   '_i15',
#   '_i16',
#   '_i17',
#   '_i18',
#   '_i19',
#   '_i20',
#   '_i21',
#   '_i22',
#   '_i23',
#   '_i24',
#   '_i25',
#   '_i27',
#   '_i28',
#   '_i29',
#   '_i3',
#   '_i30',
#   '_i31',
#   '_i32',
#   '_i33',
#   '_i34',
#   '_i35',
#   '_i36',
#   '_i37',
#   '_i38',
#   '_i39',
#   '_i4',
#   '_i40',
#   '_i41',
#   '_i42',
#   '_i43',
#   '_i44',
#   '_i45',
#   '_i46',
#   '_i47',
#   '_i49',
#   '_i5',
#   '_i50',
#   '_i51',
#   '_i52',
#   '_i53',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   '_pydevd_bundle',
#   'const',
#   'dao',
#   'datetime',
#   'engine',
#   'exit',
#   'get_ipython',
#   'hi',
#   'i',
#   'inp',
#   'keyword',
#   'matches',
#   'print_columns',
#   'pydev_jupyter_vars',
#   'pyttsx3',
#   'quit',
#   're',
#   'remove_imported_pydev_package',
#   's',
#   'sys',
#   't',
#   'total',
#   'x'],
#  '_i54': 'globals()',
#  '_54': {...},
#  '_i55': 'locals()',
#  '_55': {...},
#  '_i56': 'vars()'}
